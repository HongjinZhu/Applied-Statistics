# %%
library("ggplot2")
mu = 10
nsim = 10000

# Your code: generate nsim i.i.d. samples from Poi(mu) (~1 line)
set.seed(2023)
Y = rpois(nsim, lambda=mu)

# %%
# Your code: compute the Pearson residual for each sample (~1-2 lines)
pearson_resid = (Y - mu) / sqrt(mu)

# Your code: use ggplot to plot the following (~2-3 lines):
# 1. A normal Q-Q plot for pearson_resid;
# 2. A reference line with slope 1 and intercept 0

qqnorm(pearson_resid, main = "normal Q-Q plot for pearson_resid")
abline(a = 0, b = 1, col = 'blue')
# Out:
# Plot with title “normal Q-Q plot for pearson_resid”

# %%
# Your code: compute the deviance residual for each sample (~1-2 lines)
dev_resid = sqrt(2*(mu - Y - (log(mu) - log(Y)) * Y)) * sign(Y - mu)

# Your code: use ggplot to plot the following (~2-3 lines):
# 1. A normal Q-Q plot for dev_resid;
# 2. A reference line with slope 1 and intercept 0

qqnorm(dev_resid, main = "normal Q-Q plot for dev_resid")
abline(a = 0, b = 1, col = 'blue')
# Out:
# Plot with title “normal Q-Q plot for dev_resid”

# %%
### code link
https://colab.research.google.com/drive/1KFR8vRcK1vkf-a9eWycczzfiJZ209eQz?usp=sharing
